# %%
# import required libraries
from ifmiap import utils
from ifmiap import authenticate
from ifmiap import preprocessing
import datetime

# %%
# process certain squares using a list of grid IDs
selected_grid_id = [104, 61]
aoi_list = utils.gpd_to_json(id_list=selected_grid_id)

# define the flood date range
pre_flood_dates = utils.date_range('01/05/2020', 60)
post_flood_dates = utils.date_range('20/07/2020', 8)

# pull sentinel-1 images for pre and post flood duration
pre_s1_scenes = {aoi['properties']['ID']: 
                 utils.search_sentinel_data(
                     bbox = aoi, 
                     start_date = pre_flood_dates[0], 
                     end_date = pre_flood_dates[-1]
                 )
                 for aoi in aoi_list
                }

post_s1_scenes = {aoi['properties']['ID']: 
                 utils.search_sentinel_data(
                     bbox = aoi, 
                     start_date = post_flood_dates[0], 
                     end_date = post_flood_dates[-1]
                 )
                 for aoi in aoi_list
                }

for id in selected_grid_id:
    print(f'ID: {id}, {len(pre_s1_scenes[id])} pre flood scenes and {len(post_s1_scenes[id])} post flood scenes found.')
# Out:
# ID: 190, 25 pre flood scenes and 4 post flood scenes found.
# ID: 104, 35 pre flood scenes and 7 post flood scenes found.
# ID: 61, 35 pre flood scenes and 8 post flood scenes found.

# %%
# %%time
stacked_pre = {f'{id}':
                preprocessing.stack_images(pre_s1_scenes[id], id)
                for id in selected_grid_id
               }
stacked_post = {f'{id}':
                preprocessing.stack_images(post_s1_scenes[id], id)
                for id in selected_grid_id
               }
# Out:
# CPU times: user 7.86 s, sys: 1.14 s, total: 9 s
# Wall time: 1min 21s

# %%
# match the cell size and extent of pre and post images
for id in stacked_pre:
    stacked_post[id]['vv_stack'] = stacked_post[id]['vv_stack'].rio.reproject_match(stacked_pre[id]['vv_stack']).rio.write_transform(stacked_pre[id]['vv_stack'].rio.transform())
    stacked_post[id]['vh_stack'] = stacked_post[id]['vh_stack'].rio.reproject_match(stacked_pre[id]['vh_stack']).rio.write_transform(stacked_pre[id]['vh_stack'].rio.transform())

# %%
# %%time
for id in selected_grid_id:
    outfile_pre_vv = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/pre_vv_mean_{id}.tif'
    outfile_pre_vh = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/pre_vh_mean_{id}.tif'
    
    outfile_post_vv = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/post_vv_mean_{id}.tif'
    outfile_post_vh = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/post_vh_mean_{id}.tif'
    """
    utils.export_xarray(stacked_post[f'{id}']['vv_stack'].mean(axis=0), outfile_post_vv)
    utils.export_xarray(stacked_post[f'{id}']['vh_stack'].mean(axis=0), outfile_post_vh)
    
    utils.export_xarray(stacked_pre[f'{id}']['vv_stack'].mean(axis=0), outfile_pre_vv)
    utils.export_xarray(stacked_pre[f'{id}']['vh_stack'].mean(axis=0), outfile_pre_vh)
    """
# Out:
# CPU times: user 280 ms, sys: 193 ms, total: 473 ms
# Wall time: 506 ms

# %%
vv_thd = 2.5
vh_thd = 2.5

flood_dict = {f'{id}':
              anomaly_cells(stacked_pre[f'{id}'], stacked_post[f'{id}'], vv_thd, vh_thd)
              for id in selected_grid_id
             }

for id in flood_dict:
    outfile_flood = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/FloodExtent{id}.tif'

    utils.export_xarray(flood_dict[id], outfile_flood)
    
flood_dict[id].plot()
# Out:
# /opt/homebrew/lib/python3.9/site-packages/numpy/lib/nanfunctions.py:1878: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [114], line 4
#       1 vv_thd = 2.5
#       2 vh_thd = 2.5
# ----> 4 flood_dict = {f'{id}':
#       5               anomaly_cells(stacked_pre[f'{id}'], stacked_post[f'{id}'], vv_thd, vh_thd)
#       6               for id in selected_grid_id
#       7              }
#       9 for id in flood_dict:
#      10     outfile_flood = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/flood_{id}.tif'
#
# Cell In [114], line 5, in <dictcomp>(.0)
#       1 vv_thd = 2.5
#       2 vh_thd = 2.5
#       4 flood_dict = {f'{id}':
# ----> 5               anomaly_cells(stacked_pre[f'{id}'], stacked_post[f'{id}'], vv_thd, vh_thd)
#       6               for id in selected_grid_id
#       7              }
#       9 for id in flood_dict:
#      10     outfile_flood = f'/Users/pratyusht/Documents/MapSolveAI/ifmiap/output/flood_{id}.tif'
#
# Cell In [87], line 13, in anomaly_cells(pre_stack, post_stack, vv_thd, vh_thd)
#      11 anomaly_vh = (post_stack['vh_stack'].mean(axis=0) - pre_mean_vh) / pre_std_vh
#      12 floods_vh = (abs(anomaly_vh) > vh_thd).astype(int)
# ---> 13 floods_vh = np.where(floods_vh == 1, 2)
#      15 # combine flood extent for VV and VH bands
#      16 combined_floods = floods_vv + floods_vh
#
# File <__array_function__ internals>:180, in where(*args, **kwargs)
#
# ValueError: either both or neither of x and y should be given
